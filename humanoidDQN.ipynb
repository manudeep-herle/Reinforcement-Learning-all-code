# %%
import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.offsetbox import (OffsetImage, AnnotationBbox)
import math
import torch
import torchvision.transforms as transforms
from collections import deque
import random
import torch.nn as nn
import torch.nn.functional as F
from itertools import count
import torch.optim as optim

torch.set_default_tensor_type(torch.FloatTensor)

env = gym.make("Humanoid-v4", render_mode="human")
obs,info = env.reset()

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def plot_rewards(rewards, mode = "Training"):
  # Reward Dynamics
  plt.figure(figsize=(15, 10))
  plt.plot(rewards)
  plt.xlabel('Episode', fontsize=28)
  plt.ylabel('Reward Value', fontsize=28)
  plt.title(mode, fontsize=36)
  plt.xticks(fontsize=24)
  plt.yticks( fontsize=24)
  plt.grid()
  plt.show()

# %%
# Neural network that takes in a state and produces Q values for all actions
class Net(nn.Module):
    def __init__(self, obs_size, no_actions):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(obs_size, 648)
        self.fc2 = nn.Linear(648, 648)
        self.fc3 = nn.Linear(648, no_actions)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class RandomAgent:
  def __init__(self, env):
    self.env = env
    self.observation_space = env.observation_space
    self.action_space = env.action_space

  def step(self, obs, Q, epsilon = 1):
    # Choose action A from from state S using policy derived from Q
    rand = np.random.random()
    if rand < epsilon:
      action = env.action_space.sample()
      return torch.tensor(action, device = device)
      #Else Best action - look at Q table and see which action has the best Q value for current state (or observation)
    else:
      action = []
      out = Q(obs.type(torch.float32))
      action = torch.tensor(out, device=device, dtype=torch.float32)
      return action

agent = RandomAgent(env)
dtype=torch.float32

# %%
# Inititalization and parameters
gamma = 0.75 # discount factor
no_episodes = 500

# initial epsilon value
epsilon = 1
decay_rate = (0.01 / 1)**(1/no_episodes) # epsilon decay rate

# results stored here
reward_per_episode_train = []
epsilon_values = []

# 1. Initialize replay memory
minibatch_size = 64
D = deque(maxlen=10000)

# Init Q net and target Q net
Q = Net(376, 17).to(device)
Q_target = Net(376, 17).to(device)
# Copy weights from Q to Q_target
Q_target.load_state_dict(Q.state_dict())

# Loss function setup
criterion = nn.MSELoss() # MSE loss
optimizer = optim.SGD(Q.parameters(), lr=0.005, momentum=0.70) # stochastic gradient descent to calculate updated weights

# 4. Loop for multiple episodes.
for e in range(no_episodes):
  # 5. Initialize the state.
  new_state, _ = env.reset()
  episode_reward, terminated, truncated, epsilon = 0, False, False,  epsilon * decay_rate
  epsilon_values.append(epsilon)

  # 6. Until the episode ends
  ts = 0
  while not terminated and not truncated:
    ts += 1
    # new_state from the previous iteration is the current state now.
    curr_state = torch.tensor(new_state, device=device)

    # 7. Pick an action with probability epsilon
    action = agent.step(curr_state, Q, epsilon)

    # 8. Take action A
    new_state, reward, terminated, truncated, _ = env.step(action)
    next_state = torch.tensor(new_state, device=device)


    if not math.isnan(reward):
       episode_reward += reward
      #  print("NAN", reward, episode_reward)

    # 9. Store st, at, rt, st+1, terminated in D
    D.append([curr_state, action, reward ,next_state, terminated])

    # 10. Sample random minibatch from D (s, a, r, sp, terminated)
    if len(D) < minibatch_size:
      continue # if not enough records in replay memory, continue to next iteration

    minibatch = random.sample(D, minibatch_size)

    # For transitions in minibatch calculate error and backprop.
    loss = None
    curr_states = []
    actions = []
    targets = []
    for st, at, rt, st1, ter  in minibatch:
      yj = None
      if ter:
        continue
        # yj = torch.tensor(rt, dtype=torch.float32, device=device)
      else:
        yj = rt + gamma * Q_target(st1.type(torch.float32))# Take the max of Qc(obs)
        # yj = rt + gamma * Q_target(st1.type(torch.float32))[torch.argmax(Q(st1.type(torch.float32)))] # Take Q target(next_state or st1) for best action in Q
      curr_states.append(st)
      actions.append(at)
      targets.append(yj)

    if len(curr_states) == 0:
       continue
    curr_states = torch.stack(curr_states)
    # Q values for the selected actions for the list of curr_states
    prediction = Q(curr_states.type(torch.float32))
    # Q values for best actions from next_state
    target = torch.stack(targets).to(device)

    # Reset the leftover gradient
    optimizer.zero_grad()
    # Calculate loss
    loss = criterion(prediction, target)
    # Calculate the delta IG
    loss.backward()
    # Pass the loss to all the nodes
    optimizer.step()

    Q_target_state_dict = Q_target.state_dict()
    Q_state_dict = Q.state_dict()

    # Every step soft update the weights
    if ts:
      # update the target network weights
      for key in Q_state_dict:
            Q_target_state_dict[key] = Q_state_dict[key]*0.05 + Q_target_state_dict[key]*(1-0.05)
            Q_target.load_state_dict(Q_target_state_dict)

  reward_per_episode_train.append(episode_reward)
  print("reward after episode {0}: {1} ".format(e, episode_reward) )
print("last 10 rewards: \n", reward_per_episode_train[-10:], terminated)

plot_rewards(reward_per_episode_train)
# Out:
# reward after episode 0: 93.64228068538415
# reward after episode 1: 83.38927996678254
# C:\Users\Manudeep\AppData\Local\Temp\ipykernel_18348\881278347.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   action = torch.tensor(out, device=device, dtype=torch.float32)
# reward after episode 2: 132.07668371052526
# reward after episode 3: 134.04429169704795
# reward after episode 4: 94.44107584397727
# reward after episode 5: 101.23443784733877
# reward after episode 6: 135.9772617944737
# reward after episode 7: 116.22404982552379
# reward after episode 8: 78.24087110005382
# reward after episode 9: 116.4726796873478
# reward after episode 10: 180.23393958102582
# reward after episode 11: 84.30249737462016
# reward after episode 12: 144.5360281517728
# reward after episode 13: 86.45028473740071
# reward after episode 14: 144.83359819006964
# reward after episode 15: 253.4605015183662
# reward after episode 16: 113.84394617802604
# reward after episode 17: 85.7257742458775
# reward after episode 18: 85.69883655151526
# reward after episode 19: 100.7941570025571
# reward after episode 20: 164.09901644516685
# reward after episode 21: 92.68333233278464
# reward after episode 22: 74.81360159150238
# reward after episode 23: 126.80762293975917
# reward after episode 24: 145.30161994188575
# reward after episode 25: 68.65675769323445
# reward after episode 26: 103.21460504361586
# reward after episode 27: 86.07701926356374
# reward after episode 28: 123.55795063285098
# reward after episode 29: 157.78789711009233
# reward after episode 30: 85.06545702132267
# reward after episode 31: 93.94334148672814
# reward after episode 32: 83.5663304216484
# reward after episode 33: 105.0219596319054
# reward after episode 34: 102.46817351917609
# reward after episode 35: 142.55205194641428
# reward after episode 36: 60.48473407897698
# reward after episode 37: 64.01579198318362
# reward after episode 38: 73.87876256743608
# reward after episode 39: 136.56716241392672
# reward after episode 40: 93.78557323523536
# reward after episode 41: 104.66993407717884
# reward after episode 42: 71.92125401912323
# reward after episode 43: 135.71696000510903
# reward after episode 44: 60.57408899002086
# reward after episode 45: 79.98967313739651
# reward after episode 46: 45.835128841313356
# reward after episode 47: 88.88291599891157
# reward after episode 48: 58.782379683077444
# reward after episode 49: 88.11416296801384
# reward after episode 50: 102.71365967339382
# reward after episode 51: 69.97172758024753
# reward after episode 52: 108.70163455504077
# reward after episode 53: 65.56464087012638
# reward after episode 54: 91.55176426613923
# reward after episode 55: 44.73637097375592
# reward after episode 56: 132.36004169515488
# reward after episode 57: 140.06025639796087
# reward after episode 58: 77.45452393951419
# reward after episode 59: 82.01406741163197
# reward after episode 60: 84.45187988111488
# reward after episode 61: 53.909515079417815
# reward after episode 62: 56.147253435696236
# reward after episode 63: 56.590412120741604
# reward after episode 64: 88.49029242908718
# reward after episode 65: 64.68161274847427
# reward after episode 66: 55.344795251539736
# reward after episode 67: 44.27480216552302
# reward after episode 68: 126.09025073464105
# reward after episode 69: 116.41589241809973
# reward after episode 70: 75.73339914968628
# reward after episode 71: 77.13280259486535
# reward after episode 72: 91.66604440044689
# reward after episode 73: 86.39410133215996
# reward after episode 74: 55.46188546971164
# reward after episode 75: 49.69805522360335
# reward after episode 76: 55.43543622922825
# reward after episode 77: 79.84783112298622
# reward after episode 78: 101.24413289944994
# reward after episode 79: 89.66493297042352
# reward after episode 80: 34.44685388367172
# reward after episode 81: 39.20530710693463
# reward after episode 82: 45.08414589614077
# reward after episode 83: 55.95879249215122
# reward after episode 84: 61.57737296397966
# reward after episode 85: 77.37461730471817
# reward after episode 86: 64.08792254420231
# reward after episode 87: 36.25258021013516
# reward after episode 88: 70.94515702366374
# reward after episode 89: 85.09735571206092
# reward after episode 90: 35.34469480061382
# reward after episode 91: 81.79879600403117
# reward after episode 92: 123.62152037184747
# reward after episode 93: 86.65755558979937
# reward after episode 94: 30.193966692458538
# reward after episode 95: 41.06378772955337
# reward after episode 96: 61.89531917149347
# reward after episode 97: 61.63329529675942
# reward after episode 98: 71.68261053374239
# reward after episode 99: 67.65339719790369
# reward after episode 100: 76.52787372942734
# reward after episode 101: 59.84208289633888
# reward after episode 102: 34.40098446434837
# reward after episode 103: 49.27131791480294
# reward after episode 104: 67.18839625224827
# reward after episode 105: 67.28167607392601
# reward after episode 106: 34.41473726064466
# reward after episode 107: 44.62849641536156
# reward after episode 108: 117.67341558784075
# reward after episode 109: 19.987462124600626
# reward after episode 110: 39.22284456971568
# reward after episode 111: 30.001862652277236
# reward after episode 112: 51.534009470720086
# reward after episode 113: 50.160471913897474
# reward after episode 114: 41.104346517186954
# reward after episode 115: 35.0464243520629
# reward after episode 116: 40.7190351175898
# reward after episode 117: 50.241970784120824
# reward after episode 118: 40.36777915254988
# reward after episode 119: 50.17425214121577
# reward after episode 120: 71.10867097702933
# reward after episode 121: 35.27296362027677
# reward after episode 122: 25.873497180423893
# reward after episode 123: 45.76930351047843
# reward after episode 124: 34.86171263814938
# reward after episode 125: 40.10018053664705
# reward after episode 126: 35.56040066677568
# reward after episode 127: 19.55887823202668
# reward after episode 128: 20.05986683772143
# reward after episode 129: 24.71240502233716
# reward after episode 130: 20.825885712408898
# reward after episode 131: 46.150549936389886
# reward after episode 132: 34.75797736562202
# reward after episode 133: 45.503269893056014
# reward after episode 134: 40.26595876943279
# reward after episode 135: 76.86802194983746
# reward after episode 136: 36.087390864904215
# reward after episode 137: 49.450616922044446
# reward after episode 138: 49.90849226296918
# reward after episode 139: 30.799579542347495
# reward after episode 140: 51.45794973133728
# reward after episode 141: 35.22366566471595
# reward after episode 142: 57.92190675671155
# reward after episode 143: 63.40372933433463
# reward after episode 144: 40.033826670159954
# reward after episode 145: 86.41328944995784
# reward after episode 146: 50.60732408180668
# reward after episode 147: 29.99725774220189
# reward after episode 148: 35.0394739422792
# reward after episode 149: 67.34160339364082
# reward after episode 150: 70.49201532568492
# reward after episode 151: 55.032476532799585
# reward after episode 152: 50.954610174264104
# reward after episode 153: 35.20868364048384
# reward after episode 154: 56.71896740174675
# reward after episode 155: 58.84720606846577
# reward after episode 156: 40.53898799126021
# reward after episode 157: 25.055576528790727
# reward after episode 158: 25.160660351205586
# reward after episode 159: 26.022475355846527
# reward after episode 160: 50.74089289769157
# reward after episode 161: 30.52838412652379
# reward after episode 162: 24.52833392457464
# reward after episode 163: 25.298657888759948
# reward after episode 164: 66.90656164828557
# reward after episode 165: 25.33337227349051
# reward after episode 166: 41.35334124880566
# reward after episode 167: 65.76530338430806
# reward after episode 168: 45.947203279744016
# reward after episode 169: 36.055731125951766
# reward after episode 170: 35.650501246116015
# reward after episode 171: 25.22877764593591
# reward after episode 172: 46.20584111763504
# reward after episode 173: 20.247772400103095
# reward after episode 174: 34.96522180591703
# reward after episode 175: 30.681417073121658
# reward after episode 176: 35.36529928588091
# reward after episode 177: 36.60339266699287
# reward after episode 178: 25.429822244173785
# reward after episode 179: 14.661692424879863
# reward after episode 180: 25.0607505606169
# reward after episode 181: 20.64716270900852
# reward after episode 182: 35.80831144773055
# reward after episode 183: 30.30432547108535
# reward after episode 184: 30.460459436529064
# reward after episode 185: 25.334760392636646
# reward after episode 186: 30.520403816776682
# reward after episode 187: 25.842546537149918
# reward after episode 188: 39.06319058303192
# reward after episode 189: 19.990040691261385
# reward after episode 190: 26.118111492226344
# reward after episode 191: 4.916174304802114
# reward after episode 192: 19.669749870961493
# reward after episode 193: 30.5913400735203
# reward after episode 194: 4.90412201489871
# reward after episode 195: 40.775645135058966
# reward after episode 196: 25.86369565677407
# reward after episode 197: 25.38196879451133
# reward after episode 198: 41.45318275074344
# reward after episode 199: 31.039781152197655
# reward after episode 200: 69.25412228695596
# reward after episode 201: 20.60889018969526
# reward after episode 202: 30.31306747504813
# reward after episode 203: 24.91102506357562
# reward after episode 204: 20.623870745926286
# reward after episode 205: 30.016597814527326
# reward after episode 206: 25.639822045005094
# reward after episode 207: 39.64428812198236
# reward after episode 208: 25.253335765359374
# reward after episode 209: 15.316626775755442
# reward after episode 210: 15.416434398507592
# reward after episode 211: 20.630178515179736
# reward after episode 212: 30.90496621978598
# reward after episode 213: 20.027318912418423
# reward after episode 214: 15.094247412884712
# reward after episode 215: 10.424045154343077
# reward after episode 216: 19.75917685631017
# reward after episode 217: 19.769473197330292
# reward after episode 218: 21.109568728908194
# reward after episode 219: 20.707976126294575
# reward after episode 220: 14.747138497067013
# reward after episode 221: 31.282714122632207
# reward after episode 222: 25.831918276563798
# reward after episode 223: 20.54995260039027
# reward after episode 224: 30.565901933383238
# reward after episode 225: 25.172085647373972
# reward after episode 226: 10.181611861127246
# reward after episode 227: 15.056936757952835
# reward after episode 228: 25.442893419015604
# reward after episode 229: 25.090577938111405
# reward after episode 230: 10.172402664114497
# reward after episode 231: 15.51772287930122
# reward after episode 232: 31.083749915181585
# reward after episode 233: 20.767167064192883
# reward after episode 234: 20.941486873010188
# reward after episode 235: 10.12949398538315
# reward after episode 236: 4.914427982469817
# reward after episode 237: 26.14310289848886
# reward after episode 238: 25.456088536561616
# reward after episode 239: 30.302816727585693
# reward after episode 240: 15.280215619839018
# reward after episode 241: 30.91262757712271
# reward after episode 242: 15.701659211204175
# reward after episode 243: 10.03235248667026
# reward after episode 244: 30.24824601530133
# reward after episode 245: 10.310824087825802
# reward after episode 246: 15.58062200200242
# reward after episode 247: 20.369136840518692
# reward after episode 248: 25.455795572698463
# reward after episode 249: 25.678194153431917
# reward after episode 250: 10.266118472075451
# reward after episode 251: 15.222350792187363
# reward after episode 252: 5.208370193433172
# reward after episode 253: 14.978952362503207
# reward after episode 254: 4.94150056575263
# reward after episode 255: 15.178055460908798
# reward after episode 256: 15.031583863715227
# reward after episode 257: 30.536861566949366
# reward after episode 258: 10.247937233501872
# reward after episode 259: 19.751698810363635
# reward after episode 260: 4.967885525794173
# reward after episode 261: 5.147837814303216
# reward after episode 262: 20.58805137588388
# reward after episode 263: 34.41861180558085
# reward after episode 264: 10.001057492445835
# reward after episode 265: 29.56654091678755
# reward after episode 266: 14.97515904256342
# reward after episode 267: 26.12678168198136
# reward after episode 268: 15.086965628947022
# reward after episode 269: 10.326261743580709
# reward after episode 270: 10.090969242046501
# reward after episode 271: 5.198507399087033
# reward after episode 272: 5.0408134674821286
# reward after episode 273: 15.180762710881748
# reward after episode 274: 14.852028318266761
# reward after episode 275: 15.065916202474614
# reward after episode 276: 20.427656921932343
# reward after episode 277: 14.709998103465008
# reward after episode 278: 10.139273729853942
# reward after episode 279: 32.02342663085931
# reward after episode 280: 4.922088807873294
# reward after episode 281: 15.832716478415218
# reward after episode 282: 15.445427762585858
# reward after episode 283: 25.658140586211044
# reward after episode 284: 10.018889745737596
# reward after episode 285: 5.394528661841979
# reward after episode 286: 4.891525466853589
# reward after episode 287: 10.168120003991918
# reward after episode 288: 5.069068061958468
# reward after episode 289: 4.948347347281901
# reward after episode 290: 10.095383507259976
# reward after episode 291: 15.738848346135097
# reward after episode 292: 10.258999386728625
# reward after episode 293: 31.409850582608666
# reward after episode 294: 0
# reward after episode 295: 15.161192764710533
# reward after episode 296: 10.467879610412304
# reward after episode 297: 4.978154632121144
# reward after episode 298: 4.94098770233809
# reward after episode 299: 10.106713108782902
# reward after episode 300: 5.012959050405079
# reward after episode 301: 15.175642517217181
# reward after episode 302: 15.198577954094933
# reward after episode 303: 5.259232303676383
# reward after episode 304: 10.059216590149816
# reward after episode 305: 10.029024118044026
# reward after episode 306: 20.71960712761458
# reward after episode 307: 0
# reward after episode 308: 4.96052832040195
# reward after episode 309: 15.440435532490042
# reward after episode 310: 10.235264313062396
# reward after episode 311: 15.160762369506042
# reward after episode 312: 0
# reward after episode 313: 10.177737596598785
# reward after episode 314: 10.1078645170805
# reward after episode 315: 4.9793466017618115
# reward after episode 316: 0
# reward after episode 317: 15.448229736799087
# reward after episode 318: 5.365332502611129
# reward after episode 319: 5.132815863897294
# reward after episode 320: 15.112999455350767
# reward after episode 321: 10.251662261506901
# reward after episode 322: 15.055831912087818
# reward after episode 323: 5.119897970618426
# reward after episode 324: 14.838369215632369
# reward after episode 325: 4.99220362182327
# reward after episode 326: 0
# reward after episode 327: 4.970011510559422
# reward after episode 328: 9.854757010292268
# reward after episode 329: 5.083864795488834
# reward after episode 330: 0
# reward after episode 331: 5.196529881222079
# reward after episode 332: 19.968827898753734
# reward after episode 333: 10.431992256547623
# reward after episode 334: 10.290547986976117
# reward after episode 335: 5.028203204921398
# reward after episode 336: 4.919744973707152
# reward after episode 337: 10.151730120217511
# reward after episode 338: 0
# reward after episode 339: 4.932025886575746
# reward after episode 340: 14.939715043737063
# reward after episode 341: 15.449298589859097
# reward after episode 342: 4.874799987442457
# reward after episode 343: 4.904791170897209
# reward after episode 344: 5.068854866996541
# reward after episode 345: 0
# reward after episode 346: 5.149900344578451
# reward after episode 347: 4.94307680911722
# reward after episode 348: 0
# reward after episode 349: 4.904920512830622
# reward after episode 350: 4.945274978885941
# reward after episode 351: 15.492925899919307
# reward after episode 352: 0
# reward after episode 353: 15.09705758009834
# reward after episode 354: 0
# reward after episode 355: 15.032526232981745
# reward after episode 356: 14.693409374493164
# reward after episode 357: 15.051620032239157
# reward after episode 358: 0
# reward after episode 359: 5.083026257908399
# reward after episode 360: 5.161205875271509
# reward after episode 361: 5.304090651064762
# reward after episode 362: 0
# reward after episode 363: 5.0538405276030165
# reward after episode 364: 4.942601433507882
# reward after episode 365: 10.249372191596162
# reward after episode 366: 4.914366545680038
# reward after episode 367: 16.235083199149297
# reward after episode 368: 0
# reward after episode 369: 5.323955528366079
# reward after episode 370: 10.132580953044258
# reward after episode 371: 5.10273814339961
# reward after episode 372: 0
# reward after episode 373: 4.9021920740634215
# reward after episode 374: 10.229213034143314
# reward after episode 375: 5.167947242018021
# reward after episode 376: 4.955109827818095
# reward after episode 377: 15.437134752660715
# reward after episode 378: 9.927373220199577
# reward after episode 379: 10.015158873764289
# reward after episode 380: 5.454494989300018
# reward after episode 381: 15.43096649880571
# reward after episode 382: 10.37518756464528
# reward after episode 383: 5.0397241573338025
# reward after episode 384: 4.925445759085986
# reward after episode 385: 0
# reward after episode 386: 10.727845881172787
# reward after episode 387: 4.981991501861179
# reward after episode 388: 9.766443622052398
# reward after episode 389: 9.814178162624401
# reward after episode 390: 4.887312506123148
# reward after episode 391: 0
# reward after episode 392: 5.07695788667268
# reward after episode 393: 4.8876435616135705
# reward after episode 394: 0
# reward after episode 395: 0
# reward after episode 396: 9.772102971466403
# reward after episode 397: 0
# reward after episode 398: 0
# reward after episode 399: 0
# reward after episode 400: 5.144907347158753
# reward after episode 401: 0
# reward after episode 402: 4.916237487181253
# reward after episode 403: 4.907730247955214
# reward after episode 404: 0
# reward after episode 405: 10.591119238049561
# reward after episode 406: 5.114011912304001
# reward after episode 407: 10.175054395710747
# reward after episode 408: 14.813969631264737
# reward after episode 409: 0
# reward after episode 410: 14.962281778716562
# reward after episode 411: 4.9189495319838334
# reward after episode 412: 0
# reward after episode 413: 4.958171996269329
# reward after episode 414: 0
# reward after episode 415: 5.198900706944693
# reward after episode 416: 5.0023040154291785
# reward after episode 417: 0
# reward after episode 418: 10.189752976677827
# reward after episode 419: 0
# reward after episode 420: 4.993779084132311
# reward after episode 421: 10.023993282589299
# reward after episode 422: 4.8997742579909955
# reward after episode 423: 0
# reward after episode 424: 4.877697542038889
# reward after episode 425: 0
# reward after episode 426: 9.905530765276916
# reward after episode 427: 4.840861827140694
# reward after episode 428: 10.089826655918841
# reward after episode 429: 0
# reward after episode 430: 0
# reward after episode 431: 5.2830446459066085
# reward after episode 432: 0
# reward after episode 433: 5.028021800076091
# reward after episode 434: 4.9116333257956555
# reward after episode 435: 4.992092906926181
# reward after episode 436: 5.013744088889811
# reward after episode 437: 5.22750287437429
# reward after episode 438: 10.673077365012809
# reward after episode 439: 0
# reward after episode 440: 4.907664246791158
# reward after episode 441: 4.829109352159494
# reward after episode 442: 5.097325468749855
# reward after episode 443: 0
# reward after episode 444: 9.58774311220646
# reward after episode 445: 5.077445104904581
# reward after episode 446: 0
# reward after episode 447: 9.858110907987328
# reward after episode 448: 0
# reward after episode 449: 0
# reward after episode 450: 4.922544221660706
# reward after episode 451: 0
# reward after episode 452: 4.907232498050035
# reward after episode 453: 5.2631043843082335
# reward after episode 454: 4.903243194404366
# reward after episode 455: 0
# reward after episode 456: 0
# reward after episode 457: 4.890634703288692
# reward after episode 458: 0
# reward after episode 459: 0
# reward after episode 460: 4.996837754569145
# reward after episode 461: 0
# reward after episode 462: 4.894401070512352
# reward after episode 463: 0
# reward after episode 464: 10.08943628628585
# reward after episode 465: 0
# reward after episode 466: 0
# reward after episode 467: 0
# reward after episode 468: 4.877776322740209
# reward after episode 469: 9.976191506847528
# reward after episode 470: 0
# reward after episode 471: 0
# reward after episode 472: 0
# reward after episode 473: 4.962535884529848
# reward after episode 474: 0
# reward after episode 475: 5.014940817142245
# reward after episode 476: 10.44880364547469
# reward after episode 477: 0
# reward after episode 478: 0
# reward after episode 479: 10.392029738148663
# reward after episode 480: 0
# reward after episode 481: 5.2187616932519045
# reward after episode 482: 5.095071144648693
# reward after episode 483: 4.998616150835993
# reward after episode 484: 5.005559395714947
# reward after episode 485: 0
# reward after episode 486: 10.059150337188262
# reward after episode 487: 10.148772946829332
# reward after episode 488: 0
# reward after episode 489: 0
# reward after episode 490: 5.091199636864365
# reward after episode 491: 0
# reward after episode 492: 4.978472160517739
# reward after episode 493: 0
# reward after episode 494: 0
# reward after episode 495: 4.9522257277984485
# reward after episode 496: 4.9189261725259374
# reward after episode 497: 0
# reward after episode 498: 10.257337857985647
# reward after episode 499: 4.931432857767376
# last 10 rewards:
#  [5.091199636864365, 0, 4.978472160517739, 0, 0, 4.9522257277984485, 4.9189261725259374, 0, 10.257337857985647, 4.931432857767376] True

# %%
# Learning parameters
no_episodes = 10
reward_per_episode_test = []

# 4. Loop for multiple episodes.
for episode in range(no_episodes):
  # 5. Initialize the state.
  obs, _ = env.reset()
  episode_reward, terminated, truncated,  = 0, False, False

  ts = 0
  while not terminated:
    ts += 1
    curr_state = torch.tensor(obs, device=device)
    # 7. Pick an action with probability epsilon
    action = agent.step(curr_state, Q, 0)
    # 8. Take action A
    obs, reward, terminated, truncated, _ = env.step(action.item())
    episode_reward += reward

  reward_per_episode_test.append(episode_reward)
  print("reward after episode {0}: {1} ".format(episode, episode_reward) )
print("TOTAL REWARD: \n", reward_per_episode_test[-10:], terminated)
plot_rewards(reward_per_episode_test, "Testing")

# %%
# Epsilon-decay
plt.figure(figsize=(10, 8))
plt.plot(epsilon_values, linewidth=4)
plt.xlabel('Episode no.', fontsize=24)
plt.ylabel('Epsilon Values', fontsize=24)
plt.title('Epsilon Decay', fontsize=32)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.ylim(ymin=0, ymax=1)
plt.xlim(xmin=0, xmax=no_episodes)
plt.grid()
plt.show()
